# %%
import pandas as pd

# %%
df = pd.read_csv('Hotel_Reviews_Bookings.com.csv')

df
# Out:
#                                                   Title  \
# 0                              Wonderful place to stay.
# 1                                         It was superb
# 2                                             Very Good
# 3                                             Wonderful
# 4     Fantastic value for a new, modern and spotless...
# ...                                                 ...
# 1518                                        Exceptional
# 1519                                          Wonderful
# 1520                                          Very Good
# 1521                                          Wonderful
# 1522                                           Pleasant
#
#                                          PositiveReview   NegativeReview  \
# 0     New, comfortable apartments, close to the airp...  Nothing at all.
# 1     We had a really pleasant stay! The staff was v...              NaN
# ...

# %%
df.groupby("VisitDate").first()
# Out:
#                                                             Title  \
# VisitDate
# April 2022                      Perfect gem close to the airport.
# August 2021                                             Amazing!!
# August 2022                                             Very Good
# December 2021                    Boutique hotel in the quiet area
# December 2022                                       It was superb
# February 2022                            Great place near airport
# January 2022                                            Very Good
# July 2021                                             Exceptional
# July 2022               A warm welcome and a great place to stay!
# June 2021                                               Very Good
# June 2022                                Wonderful place to stay.
# March 2022                                              Very Good
# May 2021                                         Highly Recommend
# ...

# %%
df.groupby("VisitDate")["Score"].agg(sum)
# Out:
# <ipython-input-5-fb6dcfe016b5>:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby("VisitDate")["Score"].agg(sum)
# VisitDate
# April 2022         771.0
# August 2021        872.9
# August 2022       1151.0
# December 2021      207.0
# December 2022      282.0
# February 2022      165.0
# January 2022        94.0
# July 2021          739.6
# July 2022         1214.0
# June 2021          388.0
# June 2022         1152.0
# March 2022         193.0
# May 2021            40.0
# May 2022           825.0
# November 2021      482.0
# November 2022      778.0
# October 2021       901.0
# October 2022      1466.0
# September 2021     794.0
# September 2022    1151.6
# Name: Score, dtype: float64

# %%
pivot_table = df.pivot_table(index = "VisitDate", columns= "GroupType", values = ["Score"], aggfunc = min,)
pivot_table.head(5)
# Out:
# <ipython-input-8-eea9e561c0b4>:1: FutureWarning: The provided callable <built-in function min> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   pivot_table = df.pivot_table(index = "VisitDate", columns= "GroupType", values = ["Score"], aggfunc = min,)
#                Score
# GroupType     Couple Family Group Solo traveler
# VisitDate
# April 2022       7.0    8.0   8.0           6.0
# August 2021      7.0    5.0   7.0           6.0
# August 2022      7.0    1.0   8.0           6.0
# December 2021    8.0    8.0   8.0           6.0
# December 2022    1.0    9.0  10.0           8.0
